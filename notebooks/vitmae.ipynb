# %%
import torch

from transformers import ViTMAEConfig, ViTMAEForPreTraining

# %%
vitmaeconfig = {
        'hidden_size': 192,  # default: 786
        'num_hidden_layers': 12,  # default: 12
        'num_attention_heads': 12,  # default: 12
        'intermediate_size': 768,  # default: 3072 (4 * hidden_size)
        'hidden_dropout_prob': 0.0,  # default: 0.0
        'attention_probs_dropout_prob': 0.0,  # default: 0.0
        'image_size': 256,  # default: 224
        'patch_size': 4,  # default: 16
        'num_channels': 3,  # default: 3
        'decoder_hidden_size': 192,  # default: 512
        'decoder_num_hidden_layers': 8,  # default: 8
        'decoder_num_attention_heads': 16,  # default: 16
        'decoder_intermediate_size': 768,  # default: 2048 (4 * hidden_size)
        'mask_ratio': 0.25  # default: 0.75
    }

model = ViTMAEForPreTraining(config=ViTMAEConfig(**vitmaeconfig))
print(model.config)

print(f"Parameters: {sum(param.numel() for param in model.parameters())}")
print(f"Trainable parameters: {sum(p.numel() for p in model.parameters() if p.requires_grad)}\n")

sample = torch.randn(1, 3, 256, 256)
outputs = model(sample)
logits = outputs.logits
print(logits.shape)
# Out:
# ViTMAEConfig {
#   "attention_probs_dropout_prob": 0.0,
#   "decoder_hidden_size": 192,
#   "decoder_intermediate_size": 768,
#   "decoder_num_attention_heads": 16,
#   "decoder_num_hidden_layers": 8,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.0,
#   "hidden_size": 192,
#   "image_size": 256,
#   "initializer_range": 0.02,
#   "intermediate_size": 768,
#   "layer_norm_eps": 1e-12,
#   "mask_ratio": 0.25,
#   "model_type": "vit_mae",
#   "norm_pix_loss": false,
#   "num_attention_heads": 12,
#   "num_channels": 3,
#   "num_hidden_layers": 12,
#   "patch_size": 4,
#   "qkv_bias": true,
#   "transformers_version": "4.41.2"
# }
#
# Parameters: 10527408
# Trainable parameters: 8954160
#
# torch.Size([1, 4096, 48])

# %%
print("<- model ->")
print(model)

print("\n<- parameters ->")
for name, param in model.named_parameters():
    print(name)

print("\n<- layers ->")
for name, module in model.named_modules():
    print(f"Layer: {name}")
    if hasattr(module, "weight"):
        print(f"\tWeight shape: {name} {module.weight.shape}")
    if hasattr(module, "bias"):
        print(f"\tBias shape: {name} {module.bias.shape}")
    else:
        print(f"\tNo weights {name}")
# Out:
# <- model ->
# ViTMAEForPreTraining(
#   (vit): ViTMAEModel(
#     (embeddings): ViTMAEEmbeddings(
#       (patch_embeddings): ViTMAEPatchEmbeddings(
#         (projection): Conv2d(3, 192, kernel_size=(4, 4), stride=(4, 4))
#       )
#     )
#     (encoder): ViTMAEEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x ViTMAELayer(
#           (attention): ViTMAESdpaAttention(
#             (attention): ViTMAESdpaSelfAttention(
#               (query): Linear(in_features=192, out_features=192, bias=True)
#               (key): Linear(in_features=192, out_features=192, bias=True)
#               (value): Linear(in_features=192, out_features=192, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ViTMAESelfOutput(
#               (dense): Linear(in_features=192, out_features=192, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTMAEIntermediate(
#             (dense): Linear(in_features=192, out_features=768, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ViTMAEOutput(
#             (dense): Linear(in_features=768, out_features=192, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((192,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((192,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#     (layernorm): LayerNorm((192,), eps=1e-12, elementwise_affine=True)
#   )
#   (decoder): ViTMAEDecoder(
#     (decoder_embed): Linear(in_features=192, out_features=192, bias=True)
#     (decoder_layers): ModuleList(
#       (0-7): 8 x ViTMAELayer(
#         (attention): ViTMAESdpaAttention(
#           (attention): ViTMAESdpaSelfAttention(
#             (query): Linear(in_features=192, out_features=192, bias=True)
#             (key): Linear(in_features=192, out_features=192, bias=True)
#             (value): Linear(in_features=192, out_features=192, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (output): ViTMAESelfOutput(
#             (dense): Linear(in_features=192, out_features=192, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (intermediate): ViTMAEIntermediate(
#           (dense): Linear(in_features=192, out_features=768, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): ViTMAEOutput(
#           (dense): Linear(in_features=768, out_features=192, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#         (layernorm_before): LayerNorm((192,), eps=1e-12, elementwise_affine=True)
#         (layernorm_after): LayerNorm((192,), eps=1e-12, elementwise_affine=True)
#       )
#     )
#     (decoder_norm): LayerNorm((192,), eps=1e-12, elementwise_affine=True)
#     (decoder_pred): Linear(in_features=192, out_features=48, bias=True)
#   )
# )
#
# <- parameters ->
# vit.embeddings.cls_token
# vit.embeddings.position_embeddings
# vit.embeddings.patch_embeddings.projection.weight
# vit.embeddings.patch_embeddings.projection.bias
# vit.encoder.layer.0.attention.attention.query.weight
# vit.encoder.layer.0.attention.attention.query.bias
# vit.encoder.layer.0.attention.attention.key.weight
# vit.encoder.layer.0.attention.attention.key.bias
# vit.encoder.layer.0.attention.attention.value.weight
# vit.encoder.layer.0.attention.attention.value.bias
# vit.encoder.layer.0.attention.output.dense.weight
# vit.encoder.layer.0.attention.output.dense.bias
# vit.encoder.layer.0.intermediate.dense.weight
# vit.encoder.layer.0.intermediate.dense.bias
# vit.encoder.layer.0.output.dense.weight
# vit.encoder.layer.0.output.dense.bias
# vit.encoder.layer.0.layernorm_before.weight
# vit.encoder.layer.0.layernorm_before.bias
# vit.encoder.layer.0.layernorm_after.weight
# vit.encoder.layer.0.layernorm_after.bias
# vit.encoder.layer.1.attention.attention.query.weight
# vit.encoder.layer.1.attention.attention.query.bias
# vit.encoder.layer.1.attention.attention.key.weight
# vit.encoder.layer.1.attention.attention.key.bias
# vit.encoder.layer.1.attention.attention.value.weight
# vit.encoder.layer.1.attention.attention.value.bias
# vit.encoder.layer.1.attention.output.dense.weight
# vit.encoder.layer.1.attention.output.dense.bias
# vit.encoder.layer.1.intermediate.dense.weight
# vit.encoder.layer.1.intermediate.dense.bias
# vit.encoder.layer.1.output.dense.weight
# vit.encoder.layer.1.output.dense.bias
# vit.encoder.layer.1.layernorm_before.weight
# vit.encoder.layer.1.layernorm_before.bias
# vit.encoder.layer.1.layernorm_after.weight
# vit.encoder.layer.1.layernorm_after.bias
# vit.encoder.layer.2.attention.attention.query.weight
# vit.encoder.layer.2.attention.attention.query.bias
# vit.encoder.layer.2.attention.attention.key.weight
# vit.encoder.layer.2.attention.attention.key.bias
# vit.encoder.layer.2.attention.attention.value.weight
# vit.encoder.layer.2.attention.attention.value.bias
# vit.encoder.layer.2.attention.output.dense.weight
# vit.encoder.layer.2.attention.output.dense.bias
# vit.encoder.layer.2.intermediate.dense.weight
# vit.encoder.layer.2.intermediate.dense.bias
# vit.encoder.layer.2.output.dense.weight
# vit.encoder.layer.2.output.dense.bias
# vit.encoder.layer.2.layernorm_before.weight
# vit.encoder.layer.2.layernorm_before.bias
# vit.encoder.layer.2.layernorm_after.weight
# vit.encoder.layer.2.layernorm_after.bias
# vit.encoder.layer.3.attention.attention.query.weight
# vit.encoder.layer.3.attention.attention.query.bias
# vit.encoder.layer.3.attention.attention.key.weight
# vit.encoder.layer.3.attention.attention.key.bias
# vit.encoder.layer.3.attention.attention.value.weight
# vit.encoder.layer.3.attention.attention.value.bias
# vit.encoder.layer.3.attention.output.dense.weight
# vit.encoder.layer.3.attention.output.dense.bias
# vit.encoder.layer.3.intermediate.dense.weight
# vit.encoder.layer.3.intermediate.dense.bias
# vit.encoder.layer.3.output.dense.weight
# vit.encoder.layer.3.output.dense.bias
# vit.encoder.layer.3.layernorm_before.weight
# vit.encoder.layer.3.layernorm_before.bias
# vit.encoder.layer.3.layernorm_after.weight
# vit.encoder.layer.3.layernorm_after.bias
# vit.encoder.layer.4.attention.attention.query.weight
# vit.encoder.layer.4.attention.attention.query.bias
# vit.encoder.layer.4.attention.attention.key.weight
# vit.encoder.layer.4.attention.attention.key.bias
# vit.encoder.layer.4.attention.attention.value.weight
# vit.encoder.layer.4.attention.attention.value.bias
# vit.encoder.layer.4.attention.output.dense.weight
# vit.encoder.layer.4.attention.output.dense.bias
# vit.encoder.layer.4.intermediate.dense.weight
# vit.encoder.layer.4.intermediate.dense.bias
# vit.encoder.layer.4.output.dense.weight
# vit.encoder.layer.4.output.dense.bias
# vit.encoder.layer.4.layernorm_before.weight
# vit.encoder.layer.4.layernorm_before.bias
# vit.encoder.layer.4.layernorm_after.weight
# vit.encoder.layer.4.layernorm_after.bias
# vit.encoder.layer.5.attention.attention.query.weight
# vit.encoder.layer.5.attention.attention.query.bias
# vit.encoder.layer.5.attention.attention.key.weight
# vit.encoder.layer.5.attention.attention.key.bias
# vit.encoder.layer.5.attention.attention.value.weight
# vit.encoder.layer.5.attention.attention.value.bias
# vit.encoder.layer.5.attention.output.dense.weight
# vit.encoder.layer.5.attention.output.dense.bias
# vit.encoder.layer.5.intermediate.dense.weight
# vit.encoder.layer.5.intermediate.dense.bias
# vit.encoder.layer.5.output.dense.weight
# vit.encoder.layer.5.output.dense.bias
# vit.encoder.layer.5.layernorm_before.weight
# vit.encoder.layer.5.layernorm_before.bias
# vit.encoder.layer.5.layernorm_after.weight
# vit.encoder.layer.5.layernorm_after.bias
# vit.encoder.layer.6.attention.attention.query.weight
# vit.encoder.layer.6.attention.attention.query.bias
# vit.encoder.layer.6.attention.attention.key.weight
# vit.encoder.layer.6.attention.attention.key.bias
# vit.encoder.layer.6.attention.attention.value.weight
# vit.encoder.layer.6.attention.attention.value.bias
# vit.encoder.layer.6.attention.output.dense.weight
# vit.encoder.layer.6.attention.output.dense.bias
# vit.encoder.layer.6.intermediate.dense.weight
# vit.encoder.layer.6.intermediate.dense.bias
# vit.encoder.layer.6.output.dense.weight
# vit.encoder.layer.6.output.dense.bias
# vit.encoder.layer.6.layernorm_before.weight
# vit.encoder.layer.6.layernorm_before.bias
# vit.encoder.layer.6.layernorm_after.weight
# vit.encoder.layer.6.layernorm_after.bias
# vit.encoder.layer.7.attention.attention.query.weight
# vit.encoder.layer.7.attention.attention.query.bias
# vit.encoder.layer.7.attention.attention.key.weight
# vit.encoder.layer.7.attention.attention.key.bias
# vit.encoder.layer.7.attention.attention.value.weight
# vit.encoder.layer.7.attention.attention.value.bias
# vit.encoder.layer.7.attention.output.dense.weight
# vit.encoder.layer.7.attention.output.dense.bias
# vit.encoder.layer.7.intermediate.dense.weight
# vit.encoder.layer.7.intermediate.dense.bias
# vit.encoder.layer.7.output.dense.weight
# vit.encoder.layer.7.output.dense.bias
# vit.encoder.layer.7.layernorm_before.weight
# vit.encoder.layer.7.layernorm_before.bias
# vit.encoder.layer.7.layernorm_after.weight
# vit.encoder.layer.7.layernorm_after.bias
# vit.encoder.layer.8.attention.attention.query.weight
# vit.encoder.layer.8.attention.attention.query.bias
# vit.encoder.layer.8.attention.attention.key.weight
# vit.encoder.layer.8.attention.attention.key.bias
# vit.encoder.layer.8.attention.attention.value.weight
# vit.encoder.layer.8.attention.attention.value.bias
# vit.encoder.layer.8.attention.output.dense.weight
# vit.encoder.layer.8.attention.output.dense.bias
# vit.encoder.layer.8.intermediate.dense.weight
# vit.encoder.layer.8.intermediate.dense.bias
# vit.encoder.layer.8.output.dense.weight
# vit.encoder.layer.8.output.dense.bias
# vit.encoder.layer.8.layernorm_before.weight
# vit.encoder.layer.8.layernorm_before.bias
# vit.encoder.layer.8.layernorm_after.weight
# vit.encoder.layer.8.layernorm_after.bias
# vit.encoder.layer.9.attention.attention.query.weight
# vit.encoder.layer.9.attention.attention.query.bias
# vit.encoder.layer.9.attention.attention.key.weight
# vit.encoder.layer.9.attention.attention.key.bias
# vit.encoder.layer.9.attention.attention.value.weight
# vit.encoder.layer.9.attention.attention.value.bias
# vit.encoder.layer.9.attention.output.dense.weight
# vit.encoder.layer.9.attention.output.dense.bias
# vit.encoder.layer.9.intermediate.dense.weight
# vit.encoder.layer.9.intermediate.dense.bias
# vit.encoder.layer.9.output.dense.weight
# vit.encoder.layer.9.output.dense.bias
# vit.encoder.layer.9.layernorm_before.weight
# vit.encoder.layer.9.layernorm_before.bias
# vit.encoder.layer.9.layernorm_after.weight
# vit.encoder.layer.9.layernorm_after.bias
# vit.encoder.layer.10.attention.attention.query.weight
# vit.encoder.layer.10.attention.attention.query.bias
# vit.encoder.layer.10.attention.attention.key.weight
# vit.encoder.layer.10.attention.attention.key.bias
# vit.encoder.layer.10.attention.attention.value.weight
# vit.encoder.layer.10.attention.attention.value.bias
# vit.encoder.layer.10.attention.output.dense.weight
# vit.encoder.layer.10.attention.output.dense.bias
# vit.encoder.layer.10.intermediate.dense.weight
# vit.encoder.layer.10.intermediate.dense.bias
# vit.encoder.layer.10.output.dense.weight
# vit.encoder.layer.10.output.dense.bias
# vit.encoder.layer.10.layernorm_before.weight
# vit.encoder.layer.10.layernorm_before.bias
# vit.encoder.layer.10.layernorm_after.weight
# vit.encoder.layer.10.layernorm_after.bias
# vit.encoder.layer.11.attention.attention.query.weight
# vit.encoder.layer.11.attention.attention.query.bias
# vit.encoder.layer.11.attention.attention.key.weight
# vit.encoder.layer.11.attention.attention.key.bias
# vit.encoder.layer.11.attention.attention.value.weight
# vit.encoder.layer.11.attention.attention.value.bias
# vit.encoder.layer.11.attention.output.dense.weight
# vit.encoder.layer.11.attention.output.dense.bias
# vit.encoder.layer.11.intermediate.dense.weight
# vit.encoder.layer.11.intermediate.dense.bias
# vit.encoder.layer.11.output.dense.weight
# vit.encoder.layer.11.output.dense.bias
# vit.encoder.layer.11.layernorm_before.weight
# vit.encoder.layer.11.layernorm_before.bias
# vit.encoder.layer.11.layernorm_after.weight
# vit.encoder.layer.11.layernorm_after.bias
# vit.layernorm.weight
# vit.layernorm.bias
# decoder.mask_token
# decoder.decoder_pos_embed
# decoder.decoder_embed.weight
# decoder.decoder_embed.bias
# decoder.decoder_layers.0.attention.attention.query.weight
# decoder.decoder_layers.0.attention.attention.query.bias
# decoder.decoder_layers.0.attention.attention.key.weight
# decoder.decoder_layers.0.attention.attention.key.bias
# decoder.decoder_layers.0.attention.attention.value.weight
# decoder.decoder_layers.0.attention.attention.value.bias
# decoder.decoder_layers.0.attention.output.dense.weight
# decoder.decoder_layers.0.attention.output.dense.bias
# decoder.decoder_layers.0.intermediate.dense.weight
# decoder.decoder_layers.0.intermediate.dense.bias
# decoder.decoder_layers.0.output.dense.weight
# decoder.decoder_layers.0.output.dense.bias
# decoder.decoder_layers.0.layernorm_before.weight
# decoder.decoder_layers.0.layernorm_before.bias
# decoder.decoder_layers.0.layernorm_after.weight
# decoder.decoder_layers.0.layernorm_after.bias
# decoder.decoder_layers.1.attention.attention.query.weight
# decoder.decoder_layers.1.attention.attention.query.bias
# decoder.decoder_layers.1.attention.attention.key.weight
# decoder.decoder_layers.1.attention.attention.key.bias
# decoder.decoder_layers.1.attention.attention.value.weight
# decoder.decoder_layers.1.attention.attention.value.bias
# decoder.decoder_layers.1.attention.output.dense.weight
# decoder.decoder_layers.1.attention.output.dense.bias
# decoder.decoder_layers.1.intermediate.dense.weight
# decoder.decoder_layers.1.intermediate.dense.bias
# decoder.decoder_layers.1.output.dense.weight
# decoder.decoder_layers.1.output.dense.bias
# decoder.decoder_layers.1.layernorm_before.weight
# decoder.decoder_layers.1.layernorm_before.bias
# decoder.decoder_layers.1.layernorm_after.weight
# decoder.decoder_layers.1.layernorm_after.bias
# decoder.decoder_layers.2.attention.attention.query.weight
# decoder.decoder_layers.2.attention.attention.query.bias
# decoder.decoder_layers.2.attention.attention.key.weight
# decoder.decoder_layers.2.attention.attention.key.bias
# decoder.decoder_layers.2.attention.attention.value.weight
# decoder.decoder_layers.2.attention.attention.value.bias
# decoder.decoder_layers.2.attention.output.dense.weight
# decoder.decoder_layers.2.attention.output.dense.bias
# decoder.decoder_layers.2.intermediate.dense.weight
# decoder.decoder_layers.2.intermediate.dense.bias
# decoder.decoder_layers.2.output.dense.weight
# decoder.decoder_layers.2.output.dense.bias
# decoder.decoder_layers.2.layernorm_before.weight
# decoder.decoder_layers.2.layernorm_before.bias
# decoder.decoder_layers.2.layernorm_after.weight
# decoder.decoder_layers.2.layernorm_after.bias
# decoder.decoder_layers.3.attention.attention.query.weight
# decoder.decoder_layers.3.attention.attention.query.bias
# decoder.decoder_layers.3.attention.attention.key.weight
# decoder.decoder_layers.3.attention.attention.key.bias
# decoder.decoder_layers.3.attention.attention.value.weight
# decoder.decoder_layers.3.attention.attention.value.bias
# decoder.decoder_layers.3.attention.output.dense.weight
# decoder.decoder_layers.3.attention.output.dense.bias
# decoder.decoder_layers.3.intermediate.dense.weight
# decoder.decoder_layers.3.intermediate.dense.bias
# decoder.decoder_layers.3.output.dense.weight
# decoder.decoder_layers.3.output.dense.bias
# decoder.decoder_layers.3.layernorm_before.weight
# decoder.decoder_layers.3.layernorm_before.bias
# decoder.decoder_layers.3.layernorm_after.weight
# decoder.decoder_layers.3.layernorm_after.bias
# decoder.decoder_layers.4.attention.attention.query.weight
# decoder.decoder_layers.4.attention.attention.query.bias
# decoder.decoder_layers.4.attention.attention.key.weight
# decoder.decoder_layers.4.attention.attention.key.bias
# decoder.decoder_layers.4.attention.attention.value.weight
# decoder.decoder_layers.4.attention.attention.value.bias
# decoder.decoder_layers.4.attention.output.dense.weight
# decoder.decoder_layers.4.attention.output.dense.bias
# decoder.decoder_layers.4.intermediate.dense.weight
# decoder.decoder_layers.4.intermediate.dense.bias
# decoder.decoder_layers.4.output.dense.weight
# decoder.decoder_layers.4.output.dense.bias
# decoder.decoder_layers.4.layernorm_before.weight
# decoder.decoder_layers.4.layernorm_before.bias
# decoder.decoder_layers.4.layernorm_after.weight
# decoder.decoder_layers.4.layernorm_after.bias
# decoder.decoder_layers.5.attention.attention.query.weight
# decoder.decoder_layers.5.attention.attention.query.bias
# decoder.decoder_layers.5.attention.attention.key.weight
# decoder.decoder_layers.5.attention.attention.key.bias
# decoder.decoder_layers.5.attention.attention.value.weight
# decoder.decoder_layers.5.attention.attention.value.bias
# decoder.decoder_layers.5.attention.output.dense.weight
# decoder.decoder_layers.5.attention.output.dense.bias
# decoder.decoder_layers.5.intermediate.dense.weight
# decoder.decoder_layers.5.intermediate.dense.bias
# decoder.decoder_layers.5.output.dense.weight
# decoder.decoder_layers.5.output.dense.bias
# decoder.decoder_layers.5.layernorm_before.weight
# decoder.decoder_layers.5.layernorm_before.bias
# decoder.decoder_layers.5.layernorm_after.weight
# decoder.decoder_layers.5.layernorm_after.bias
# decoder.decoder_layers.6.attention.attention.query.weight
# decoder.decoder_layers.6.attention.attention.query.bias
# decoder.decoder_layers.6.attention.attention.key.weight
# decoder.decoder_layers.6.attention.attention.key.bias
# decoder.decoder_layers.6.attention.attention.value.weight
# decoder.decoder_layers.6.attention.attention.value.bias
# decoder.decoder_layers.6.attention.output.dense.weight
# decoder.decoder_layers.6.attention.output.dense.bias
# decoder.decoder_layers.6.intermediate.dense.weight
# decoder.decoder_layers.6.intermediate.dense.bias
# decoder.decoder_layers.6.output.dense.weight
# decoder.decoder_layers.6.output.dense.bias
# decoder.decoder_layers.6.layernorm_before.weight
# decoder.decoder_layers.6.layernorm_before.bias
# decoder.decoder_layers.6.layernorm_after.weight
# decoder.decoder_layers.6.layernorm_after.bias
# decoder.decoder_layers.7.attention.attention.query.weight
# decoder.decoder_layers.7.attention.attention.query.bias
# decoder.decoder_layers.7.attention.attention.key.weight
# decoder.decoder_layers.7.attention.attention.key.bias
# decoder.decoder_layers.7.attention.attention.value.weight
# decoder.decoder_layers.7.attention.attention.value.bias
# decoder.decoder_layers.7.attention.output.dense.weight
# decoder.decoder_layers.7.attention.output.dense.bias
# decoder.decoder_layers.7.intermediate.dense.weight
# decoder.decoder_layers.7.intermediate.dense.bias
# decoder.decoder_layers.7.output.dense.weight
# decoder.decoder_layers.7.output.dense.bias
# decoder.decoder_layers.7.layernorm_before.weight
# decoder.decoder_layers.7.layernorm_before.bias
# decoder.decoder_layers.7.layernorm_after.weight
# decoder.decoder_layers.7.layernorm_after.bias
# decoder.decoder_norm.weight
# decoder.decoder_norm.bias
# decoder.decoder_pred.weight
# decoder.decoder_pred.bias
#
# <- layers ->
# Layer:
# 	No weights
# Layer: vit
# 	No weights vit
# Layer: vit.embeddings
# 	No weights vit.embeddings
# Layer: vit.embeddings.patch_embeddings
# 	No weights vit.embeddings.patch_embeddings
# Layer: vit.embeddings.patch_embeddings.projection
# 	Weight shape: vit.embeddings.patch_embeddings.projection torch.Size([192, 3, 4, 4])
# 	Bias shape: vit.embeddings.patch_embeddings.projection torch.Size([192])
# Layer: vit.encoder
# 	No weights vit.encoder
# Layer: vit.encoder.layer
# 	No weights vit.encoder.layer
# Layer: vit.encoder.layer.0
# 	No weights vit.encoder.layer.0
# Layer: vit.encoder.layer.0.attention
# 	No weights vit.encoder.layer.0.attention
# Layer: vit.encoder.layer.0.attention.attention
# 	No weights vit.encoder.layer.0.attention.attention
# Layer: vit.encoder.layer.0.attention.attention.query
# 	Weight shape: vit.encoder.layer.0.attention.attention.query torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.0.attention.attention.query torch.Size([192])
# Layer: vit.encoder.layer.0.attention.attention.key
# 	Weight shape: vit.encoder.layer.0.attention.attention.key torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.0.attention.attention.key torch.Size([192])
# Layer: vit.encoder.layer.0.attention.attention.value
# 	Weight shape: vit.encoder.layer.0.attention.attention.value torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.0.attention.attention.value torch.Size([192])
# Layer: vit.encoder.layer.0.attention.attention.dropout
# 	No weights vit.encoder.layer.0.attention.attention.dropout
# Layer: vit.encoder.layer.0.attention.output
# 	No weights vit.encoder.layer.0.attention.output
# Layer: vit.encoder.layer.0.attention.output.dense
# 	Weight shape: vit.encoder.layer.0.attention.output.dense torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.0.attention.output.dense torch.Size([192])
# Layer: vit.encoder.layer.0.attention.output.dropout
# 	No weights vit.encoder.layer.0.attention.output.dropout
# Layer: vit.encoder.layer.0.intermediate
# 	No weights vit.encoder.layer.0.intermediate
# Layer: vit.encoder.layer.0.intermediate.dense
# 	Weight shape: vit.encoder.layer.0.intermediate.dense torch.Size([768, 192])
# 	Bias shape: vit.encoder.layer.0.intermediate.dense torch.Size([768])
# Layer: vit.encoder.layer.0.intermediate.intermediate_act_fn
# 	No weights vit.encoder.layer.0.intermediate.intermediate_act_fn
# Layer: vit.encoder.layer.0.output
# 	No weights vit.encoder.layer.0.output
# Layer: vit.encoder.layer.0.output.dense
# 	Weight shape: vit.encoder.layer.0.output.dense torch.Size([192, 768])
# 	Bias shape: vit.encoder.layer.0.output.dense torch.Size([192])
# Layer: vit.encoder.layer.0.output.dropout
# 	No weights vit.encoder.layer.0.output.dropout
# Layer: vit.encoder.layer.0.layernorm_before
# 	Weight shape: vit.encoder.layer.0.layernorm_before torch.Size([192])
# 	Bias shape: vit.encoder.layer.0.layernorm_before torch.Size([192])
# Layer: vit.encoder.layer.0.layernorm_after
# 	Weight shape: vit.encoder.layer.0.layernorm_after torch.Size([192])
# 	Bias shape: vit.encoder.layer.0.layernorm_after torch.Size([192])
# Layer: vit.encoder.layer.1
# 	No weights vit.encoder.layer.1
# Layer: vit.encoder.layer.1.attention
# 	No weights vit.encoder.layer.1.attention
# Layer: vit.encoder.layer.1.attention.attention
# 	No weights vit.encoder.layer.1.attention.attention
# Layer: vit.encoder.layer.1.attention.attention.query
# 	Weight shape: vit.encoder.layer.1.attention.attention.query torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.1.attention.attention.query torch.Size([192])
# Layer: vit.encoder.layer.1.attention.attention.key
# 	Weight shape: vit.encoder.layer.1.attention.attention.key torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.1.attention.attention.key torch.Size([192])
# Layer: vit.encoder.layer.1.attention.attention.value
# 	Weight shape: vit.encoder.layer.1.attention.attention.value torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.1.attention.attention.value torch.Size([192])
# Layer: vit.encoder.layer.1.attention.attention.dropout
# 	No weights vit.encoder.layer.1.attention.attention.dropout
# Layer: vit.encoder.layer.1.attention.output
# 	No weights vit.encoder.layer.1.attention.output
# Layer: vit.encoder.layer.1.attention.output.dense
# 	Weight shape: vit.encoder.layer.1.attention.output.dense torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.1.attention.output.dense torch.Size([192])
# Layer: vit.encoder.layer.1.attention.output.dropout
# 	No weights vit.encoder.layer.1.attention.output.dropout
# Layer: vit.encoder.layer.1.intermediate
# 	No weights vit.encoder.layer.1.intermediate
# Layer: vit.encoder.layer.1.intermediate.dense
# 	Weight shape: vit.encoder.layer.1.intermediate.dense torch.Size([768, 192])
# 	Bias shape: vit.encoder.layer.1.intermediate.dense torch.Size([768])
# Layer: vit.encoder.layer.1.intermediate.intermediate_act_fn
# 	No weights vit.encoder.layer.1.intermediate.intermediate_act_fn
# Layer: vit.encoder.layer.1.output
# 	No weights vit.encoder.layer.1.output
# Layer: vit.encoder.layer.1.output.dense
# 	Weight shape: vit.encoder.layer.1.output.dense torch.Size([192, 768])
# 	Bias shape: vit.encoder.layer.1.output.dense torch.Size([192])
# Layer: vit.encoder.layer.1.output.dropout
# 	No weights vit.encoder.layer.1.output.dropout
# Layer: vit.encoder.layer.1.layernorm_before
# 	Weight shape: vit.encoder.layer.1.layernorm_before torch.Size([192])
# 	Bias shape: vit.encoder.layer.1.layernorm_before torch.Size([192])
# Layer: vit.encoder.layer.1.layernorm_after
# 	Weight shape: vit.encoder.layer.1.layernorm_after torch.Size([192])
# 	Bias shape: vit.encoder.layer.1.layernorm_after torch.Size([192])
# Layer: vit.encoder.layer.2
# 	No weights vit.encoder.layer.2
# Layer: vit.encoder.layer.2.attention
# 	No weights vit.encoder.layer.2.attention
# Layer: vit.encoder.layer.2.attention.attention
# 	No weights vit.encoder.layer.2.attention.attention
# Layer: vit.encoder.layer.2.attention.attention.query
# 	Weight shape: vit.encoder.layer.2.attention.attention.query torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.2.attention.attention.query torch.Size([192])
# Layer: vit.encoder.layer.2.attention.attention.key
# 	Weight shape: vit.encoder.layer.2.attention.attention.key torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.2.attention.attention.key torch.Size([192])
# Layer: vit.encoder.layer.2.attention.attention.value
# 	Weight shape: vit.encoder.layer.2.attention.attention.value torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.2.attention.attention.value torch.Size([192])
# Layer: vit.encoder.layer.2.attention.attention.dropout
# 	No weights vit.encoder.layer.2.attention.attention.dropout
# Layer: vit.encoder.layer.2.attention.output
# 	No weights vit.encoder.layer.2.attention.output
# Layer: vit.encoder.layer.2.attention.output.dense
# 	Weight shape: vit.encoder.layer.2.attention.output.dense torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.2.attention.output.dense torch.Size([192])
# Layer: vit.encoder.layer.2.attention.output.dropout
# 	No weights vit.encoder.layer.2.attention.output.dropout
# Layer: vit.encoder.layer.2.intermediate
# 	No weights vit.encoder.layer.2.intermediate
# Layer: vit.encoder.layer.2.intermediate.dense
# 	Weight shape: vit.encoder.layer.2.intermediate.dense torch.Size([768, 192])
# 	Bias shape: vit.encoder.layer.2.intermediate.dense torch.Size([768])
# Layer: vit.encoder.layer.2.intermediate.intermediate_act_fn
# 	No weights vit.encoder.layer.2.intermediate.intermediate_act_fn
# Layer: vit.encoder.layer.2.output
# 	No weights vit.encoder.layer.2.output
# Layer: vit.encoder.layer.2.output.dense
# 	Weight shape: vit.encoder.layer.2.output.dense torch.Size([192, 768])
# 	Bias shape: vit.encoder.layer.2.output.dense torch.Size([192])
# Layer: vit.encoder.layer.2.output.dropout
# 	No weights vit.encoder.layer.2.output.dropout
# Layer: vit.encoder.layer.2.layernorm_before
# 	Weight shape: vit.encoder.layer.2.layernorm_before torch.Size([192])
# 	Bias shape: vit.encoder.layer.2.layernorm_before torch.Size([192])
# Layer: vit.encoder.layer.2.layernorm_after
# 	Weight shape: vit.encoder.layer.2.layernorm_after torch.Size([192])
# 	Bias shape: vit.encoder.layer.2.layernorm_after torch.Size([192])
# Layer: vit.encoder.layer.3
# 	No weights vit.encoder.layer.3
# Layer: vit.encoder.layer.3.attention
# 	No weights vit.encoder.layer.3.attention
# Layer: vit.encoder.layer.3.attention.attention
# 	No weights vit.encoder.layer.3.attention.attention
# Layer: vit.encoder.layer.3.attention.attention.query
# 	Weight shape: vit.encoder.layer.3.attention.attention.query torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.3.attention.attention.query torch.Size([192])
# Layer: vit.encoder.layer.3.attention.attention.key
# 	Weight shape: vit.encoder.layer.3.attention.attention.key torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.3.attention.attention.key torch.Size([192])
# Layer: vit.encoder.layer.3.attention.attention.value
# 	Weight shape: vit.encoder.layer.3.attention.attention.value torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.3.attention.attention.value torch.Size([192])
# Layer: vit.encoder.layer.3.attention.attention.dropout
# 	No weights vit.encoder.layer.3.attention.attention.dropout
# Layer: vit.encoder.layer.3.attention.output
# 	No weights vit.encoder.layer.3.attention.output
# Layer: vit.encoder.layer.3.attention.output.dense
# 	Weight shape: vit.encoder.layer.3.attention.output.dense torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.3.attention.output.dense torch.Size([192])
# Layer: vit.encoder.layer.3.attention.output.dropout
# 	No weights vit.encoder.layer.3.attention.output.dropout
# Layer: vit.encoder.layer.3.intermediate
# 	No weights vit.encoder.layer.3.intermediate
# Layer: vit.encoder.layer.3.intermediate.dense
# 	Weight shape: vit.encoder.layer.3.intermediate.dense torch.Size([768, 192])
# 	Bias shape: vit.encoder.layer.3.intermediate.dense torch.Size([768])
# Layer: vit.encoder.layer.3.intermediate.intermediate_act_fn
# 	No weights vit.encoder.layer.3.intermediate.intermediate_act_fn
# Layer: vit.encoder.layer.3.output
# 	No weights vit.encoder.layer.3.output
# Layer: vit.encoder.layer.3.output.dense
# 	Weight shape: vit.encoder.layer.3.output.dense torch.Size([192, 768])
# 	Bias shape: vit.encoder.layer.3.output.dense torch.Size([192])
# Layer: vit.encoder.layer.3.output.dropout
# 	No weights vit.encoder.layer.3.output.dropout
# Layer: vit.encoder.layer.3.layernorm_before
# 	Weight shape: vit.encoder.layer.3.layernorm_before torch.Size([192])
# 	Bias shape: vit.encoder.layer.3.layernorm_before torch.Size([192])
# Layer: vit.encoder.layer.3.layernorm_after
# 	Weight shape: vit.encoder.layer.3.layernorm_after torch.Size([192])
# 	Bias shape: vit.encoder.layer.3.layernorm_after torch.Size([192])
# Layer: vit.encoder.layer.4
# 	No weights vit.encoder.layer.4
# Layer: vit.encoder.layer.4.attention
# 	No weights vit.encoder.layer.4.attention
# Layer: vit.encoder.layer.4.attention.attention
# 	No weights vit.encoder.layer.4.attention.attention
# Layer: vit.encoder.layer.4.attention.attention.query
# 	Weight shape: vit.encoder.layer.4.attention.attention.query torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.4.attention.attention.query torch.Size([192])
# Layer: vit.encoder.layer.4.attention.attention.key
# 	Weight shape: vit.encoder.layer.4.attention.attention.key torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.4.attention.attention.key torch.Size([192])
# Layer: vit.encoder.layer.4.attention.attention.value
# 	Weight shape: vit.encoder.layer.4.attention.attention.value torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.4.attention.attention.value torch.Size([192])
# Layer: vit.encoder.layer.4.attention.attention.dropout
# 	No weights vit.encoder.layer.4.attention.attention.dropout
# Layer: vit.encoder.layer.4.attention.output
# 	No weights vit.encoder.layer.4.attention.output
# Layer: vit.encoder.layer.4.attention.output.dense
# 	Weight shape: vit.encoder.layer.4.attention.output.dense torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.4.attention.output.dense torch.Size([192])
# Layer: vit.encoder.layer.4.attention.output.dropout
# 	No weights vit.encoder.layer.4.attention.output.dropout
# Layer: vit.encoder.layer.4.intermediate
# 	No weights vit.encoder.layer.4.intermediate
# Layer: vit.encoder.layer.4.intermediate.dense
# 	Weight shape: vit.encoder.layer.4.intermediate.dense torch.Size([768, 192])
# 	Bias shape: vit.encoder.layer.4.intermediate.dense torch.Size([768])
# Layer: vit.encoder.layer.4.intermediate.intermediate_act_fn
# 	No weights vit.encoder.layer.4.intermediate.intermediate_act_fn
# Layer: vit.encoder.layer.4.output
# 	No weights vit.encoder.layer.4.output
# Layer: vit.encoder.layer.4.output.dense
# 	Weight shape: vit.encoder.layer.4.output.dense torch.Size([192, 768])
# 	Bias shape: vit.encoder.layer.4.output.dense torch.Size([192])
# Layer: vit.encoder.layer.4.output.dropout
# 	No weights vit.encoder.layer.4.output.dropout
# Layer: vit.encoder.layer.4.layernorm_before
# 	Weight shape: vit.encoder.layer.4.layernorm_before torch.Size([192])
# 	Bias shape: vit.encoder.layer.4.layernorm_before torch.Size([192])
# Layer: vit.encoder.layer.4.layernorm_after
# 	Weight shape: vit.encoder.layer.4.layernorm_after torch.Size([192])
# 	Bias shape: vit.encoder.layer.4.layernorm_after torch.Size([192])
# Layer: vit.encoder.layer.5
# 	No weights vit.encoder.layer.5
# Layer: vit.encoder.layer.5.attention
# 	No weights vit.encoder.layer.5.attention
# Layer: vit.encoder.layer.5.attention.attention
# 	No weights vit.encoder.layer.5.attention.attention
# Layer: vit.encoder.layer.5.attention.attention.query
# 	Weight shape: vit.encoder.layer.5.attention.attention.query torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.5.attention.attention.query torch.Size([192])
# Layer: vit.encoder.layer.5.attention.attention.key
# 	Weight shape: vit.encoder.layer.5.attention.attention.key torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.5.attention.attention.key torch.Size([192])
# Layer: vit.encoder.layer.5.attention.attention.value
# 	Weight shape: vit.encoder.layer.5.attention.attention.value torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.5.attention.attention.value torch.Size([192])
# Layer: vit.encoder.layer.5.attention.attention.dropout
# 	No weights vit.encoder.layer.5.attention.attention.dropout
# Layer: vit.encoder.layer.5.attention.output
# 	No weights vit.encoder.layer.5.attention.output
# Layer: vit.encoder.layer.5.attention.output.dense
# 	Weight shape: vit.encoder.layer.5.attention.output.dense torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.5.attention.output.dense torch.Size([192])
# Layer: vit.encoder.layer.5.attention.output.dropout
# 	No weights vit.encoder.layer.5.attention.output.dropout
# Layer: vit.encoder.layer.5.intermediate
# 	No weights vit.encoder.layer.5.intermediate
# Layer: vit.encoder.layer.5.intermediate.dense
# 	Weight shape: vit.encoder.layer.5.intermediate.dense torch.Size([768, 192])
# 	Bias shape: vit.encoder.layer.5.intermediate.dense torch.Size([768])
# Layer: vit.encoder.layer.5.intermediate.intermediate_act_fn
# 	No weights vit.encoder.layer.5.intermediate.intermediate_act_fn
# Layer: vit.encoder.layer.5.output
# 	No weights vit.encoder.layer.5.output
# Layer: vit.encoder.layer.5.output.dense
# 	Weight shape: vit.encoder.layer.5.output.dense torch.Size([192, 768])
# 	Bias shape: vit.encoder.layer.5.output.dense torch.Size([192])
# Layer: vit.encoder.layer.5.output.dropout
# 	No weights vit.encoder.layer.5.output.dropout
# Layer: vit.encoder.layer.5.layernorm_before
# 	Weight shape: vit.encoder.layer.5.layernorm_before torch.Size([192])
# 	Bias shape: vit.encoder.layer.5.layernorm_before torch.Size([192])
# Layer: vit.encoder.layer.5.layernorm_after
# 	Weight shape: vit.encoder.layer.5.layernorm_after torch.Size([192])
# 	Bias shape: vit.encoder.layer.5.layernorm_after torch.Size([192])
# Layer: vit.encoder.layer.6
# 	No weights vit.encoder.layer.6
# Layer: vit.encoder.layer.6.attention
# 	No weights vit.encoder.layer.6.attention
# Layer: vit.encoder.layer.6.attention.attention
# 	No weights vit.encoder.layer.6.attention.attention
# Layer: vit.encoder.layer.6.attention.attention.query
# 	Weight shape: vit.encoder.layer.6.attention.attention.query torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.6.attention.attention.query torch.Size([192])
# Layer: vit.encoder.layer.6.attention.attention.key
# 	Weight shape: vit.encoder.layer.6.attention.attention.key torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.6.attention.attention.key torch.Size([192])
# Layer: vit.encoder.layer.6.attention.attention.value
# 	Weight shape: vit.encoder.layer.6.attention.attention.value torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.6.attention.attention.value torch.Size([192])
# Layer: vit.encoder.layer.6.attention.attention.dropout
# 	No weights vit.encoder.layer.6.attention.attention.dropout
# Layer: vit.encoder.layer.6.attention.output
# 	No weights vit.encoder.layer.6.attention.output
# Layer: vit.encoder.layer.6.attention.output.dense
# 	Weight shape: vit.encoder.layer.6.attention.output.dense torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.6.attention.output.dense torch.Size([192])
# Layer: vit.encoder.layer.6.attention.output.dropout
# 	No weights vit.encoder.layer.6.attention.output.dropout
# Layer: vit.encoder.layer.6.intermediate
# 	No weights vit.encoder.layer.6.intermediate
# Layer: vit.encoder.layer.6.intermediate.dense
# 	Weight shape: vit.encoder.layer.6.intermediate.dense torch.Size([768, 192])
# 	Bias shape: vit.encoder.layer.6.intermediate.dense torch.Size([768])
# Layer: vit.encoder.layer.6.intermediate.intermediate_act_fn
# 	No weights vit.encoder.layer.6.intermediate.intermediate_act_fn
# Layer: vit.encoder.layer.6.output
# 	No weights vit.encoder.layer.6.output
# Layer: vit.encoder.layer.6.output.dense
# 	Weight shape: vit.encoder.layer.6.output.dense torch.Size([192, 768])
# 	Bias shape: vit.encoder.layer.6.output.dense torch.Size([192])
# Layer: vit.encoder.layer.6.output.dropout
# 	No weights vit.encoder.layer.6.output.dropout
# Layer: vit.encoder.layer.6.layernorm_before
# 	Weight shape: vit.encoder.layer.6.layernorm_before torch.Size([192])
# 	Bias shape: vit.encoder.layer.6.layernorm_before torch.Size([192])
# Layer: vit.encoder.layer.6.layernorm_after
# 	Weight shape: vit.encoder.layer.6.layernorm_after torch.Size([192])
# 	Bias shape: vit.encoder.layer.6.layernorm_after torch.Size([192])
# Layer: vit.encoder.layer.7
# 	No weights vit.encoder.layer.7
# Layer: vit.encoder.layer.7.attention
# 	No weights vit.encoder.layer.7.attention
# Layer: vit.encoder.layer.7.attention.attention
# 	No weights vit.encoder.layer.7.attention.attention
# Layer: vit.encoder.layer.7.attention.attention.query
# 	Weight shape: vit.encoder.layer.7.attention.attention.query torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.7.attention.attention.query torch.Size([192])
# Layer: vit.encoder.layer.7.attention.attention.key
# 	Weight shape: vit.encoder.layer.7.attention.attention.key torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.7.attention.attention.key torch.Size([192])
# Layer: vit.encoder.layer.7.attention.attention.value
# 	Weight shape: vit.encoder.layer.7.attention.attention.value torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.7.attention.attention.value torch.Size([192])
# Layer: vit.encoder.layer.7.attention.attention.dropout
# 	No weights vit.encoder.layer.7.attention.attention.dropout
# Layer: vit.encoder.layer.7.attention.output
# 	No weights vit.encoder.layer.7.attention.output
# Layer: vit.encoder.layer.7.attention.output.dense
# 	Weight shape: vit.encoder.layer.7.attention.output.dense torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.7.attention.output.dense torch.Size([192])
# Layer: vit.encoder.layer.7.attention.output.dropout
# 	No weights vit.encoder.layer.7.attention.output.dropout
# Layer: vit.encoder.layer.7.intermediate
# 	No weights vit.encoder.layer.7.intermediate
# Layer: vit.encoder.layer.7.intermediate.dense
# 	Weight shape: vit.encoder.layer.7.intermediate.dense torch.Size([768, 192])
# 	Bias shape: vit.encoder.layer.7.intermediate.dense torch.Size([768])
# Layer: vit.encoder.layer.7.intermediate.intermediate_act_fn
# 	No weights vit.encoder.layer.7.intermediate.intermediate_act_fn
# Layer: vit.encoder.layer.7.output
# 	No weights vit.encoder.layer.7.output
# Layer: vit.encoder.layer.7.output.dense
# 	Weight shape: vit.encoder.layer.7.output.dense torch.Size([192, 768])
# 	Bias shape: vit.encoder.layer.7.output.dense torch.Size([192])
# Layer: vit.encoder.layer.7.output.dropout
# 	No weights vit.encoder.layer.7.output.dropout
# Layer: vit.encoder.layer.7.layernorm_before
# 	Weight shape: vit.encoder.layer.7.layernorm_before torch.Size([192])
# 	Bias shape: vit.encoder.layer.7.layernorm_before torch.Size([192])
# Layer: vit.encoder.layer.7.layernorm_after
# 	Weight shape: vit.encoder.layer.7.layernorm_after torch.Size([192])
# 	Bias shape: vit.encoder.layer.7.layernorm_after torch.Size([192])
# Layer: vit.encoder.layer.8
# 	No weights vit.encoder.layer.8
# Layer: vit.encoder.layer.8.attention
# 	No weights vit.encoder.layer.8.attention
# Layer: vit.encoder.layer.8.attention.attention
# 	No weights vit.encoder.layer.8.attention.attention
# Layer: vit.encoder.layer.8.attention.attention.query
# 	Weight shape: vit.encoder.layer.8.attention.attention.query torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.8.attention.attention.query torch.Size([192])
# Layer: vit.encoder.layer.8.attention.attention.key
# 	Weight shape: vit.encoder.layer.8.attention.attention.key torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.8.attention.attention.key torch.Size([192])
# Layer: vit.encoder.layer.8.attention.attention.value
# 	Weight shape: vit.encoder.layer.8.attention.attention.value torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.8.attention.attention.value torch.Size([192])
# Layer: vit.encoder.layer.8.attention.attention.dropout
# 	No weights vit.encoder.layer.8.attention.attention.dropout
# Layer: vit.encoder.layer.8.attention.output
# 	No weights vit.encoder.layer.8.attention.output
# Layer: vit.encoder.layer.8.attention.output.dense
# 	Weight shape: vit.encoder.layer.8.attention.output.dense torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.8.attention.output.dense torch.Size([192])
# Layer: vit.encoder.layer.8.attention.output.dropout
# 	No weights vit.encoder.layer.8.attention.output.dropout
# Layer: vit.encoder.layer.8.intermediate
# 	No weights vit.encoder.layer.8.intermediate
# Layer: vit.encoder.layer.8.intermediate.dense
# 	Weight shape: vit.encoder.layer.8.intermediate.dense torch.Size([768, 192])
# 	Bias shape: vit.encoder.layer.8.intermediate.dense torch.Size([768])
# Layer: vit.encoder.layer.8.intermediate.intermediate_act_fn
# 	No weights vit.encoder.layer.8.intermediate.intermediate_act_fn
# Layer: vit.encoder.layer.8.output
# 	No weights vit.encoder.layer.8.output
# Layer: vit.encoder.layer.8.output.dense
# 	Weight shape: vit.encoder.layer.8.output.dense torch.Size([192, 768])
# 	Bias shape: vit.encoder.layer.8.output.dense torch.Size([192])
# Layer: vit.encoder.layer.8.output.dropout
# 	No weights vit.encoder.layer.8.output.dropout
# Layer: vit.encoder.layer.8.layernorm_before
# 	Weight shape: vit.encoder.layer.8.layernorm_before torch.Size([192])
# 	Bias shape: vit.encoder.layer.8.layernorm_before torch.Size([192])
# Layer: vit.encoder.layer.8.layernorm_after
# 	Weight shape: vit.encoder.layer.8.layernorm_after torch.Size([192])
# 	Bias shape: vit.encoder.layer.8.layernorm_after torch.Size([192])
# Layer: vit.encoder.layer.9
# 	No weights vit.encoder.layer.9
# Layer: vit.encoder.layer.9.attention
# 	No weights vit.encoder.layer.9.attention
# Layer: vit.encoder.layer.9.attention.attention
# 	No weights vit.encoder.layer.9.attention.attention
# Layer: vit.encoder.layer.9.attention.attention.query
# 	Weight shape: vit.encoder.layer.9.attention.attention.query torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.9.attention.attention.query torch.Size([192])
# Layer: vit.encoder.layer.9.attention.attention.key
# 	Weight shape: vit.encoder.layer.9.attention.attention.key torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.9.attention.attention.key torch.Size([192])
# Layer: vit.encoder.layer.9.attention.attention.value
# 	Weight shape: vit.encoder.layer.9.attention.attention.value torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.9.attention.attention.value torch.Size([192])
# Layer: vit.encoder.layer.9.attention.attention.dropout
# 	No weights vit.encoder.layer.9.attention.attention.dropout
# Layer: vit.encoder.layer.9.attention.output
# 	No weights vit.encoder.layer.9.attention.output
# Layer: vit.encoder.layer.9.attention.output.dense
# 	Weight shape: vit.encoder.layer.9.attention.output.dense torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.9.attention.output.dense torch.Size([192])
# Layer: vit.encoder.layer.9.attention.output.dropout
# 	No weights vit.encoder.layer.9.attention.output.dropout
# Layer: vit.encoder.layer.9.intermediate
# 	No weights vit.encoder.layer.9.intermediate
# Layer: vit.encoder.layer.9.intermediate.dense
# 	Weight shape: vit.encoder.layer.9.intermediate.dense torch.Size([768, 192])
# 	Bias shape: vit.encoder.layer.9.intermediate.dense torch.Size([768])
# Layer: vit.encoder.layer.9.intermediate.intermediate_act_fn
# 	No weights vit.encoder.layer.9.intermediate.intermediate_act_fn
# Layer: vit.encoder.layer.9.output
# 	No weights vit.encoder.layer.9.output
# Layer: vit.encoder.layer.9.output.dense
# 	Weight shape: vit.encoder.layer.9.output.dense torch.Size([192, 768])
# 	Bias shape: vit.encoder.layer.9.output.dense torch.Size([192])
# Layer: vit.encoder.layer.9.output.dropout
# 	No weights vit.encoder.layer.9.output.dropout
# Layer: vit.encoder.layer.9.layernorm_before
# 	Weight shape: vit.encoder.layer.9.layernorm_before torch.Size([192])
# 	Bias shape: vit.encoder.layer.9.layernorm_before torch.Size([192])
# Layer: vit.encoder.layer.9.layernorm_after
# 	Weight shape: vit.encoder.layer.9.layernorm_after torch.Size([192])
# 	Bias shape: vit.encoder.layer.9.layernorm_after torch.Size([192])
# Layer: vit.encoder.layer.10
# 	No weights vit.encoder.layer.10
# Layer: vit.encoder.layer.10.attention
# 	No weights vit.encoder.layer.10.attention
# Layer: vit.encoder.layer.10.attention.attention
# 	No weights vit.encoder.layer.10.attention.attention
# Layer: vit.encoder.layer.10.attention.attention.query
# 	Weight shape: vit.encoder.layer.10.attention.attention.query torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.10.attention.attention.query torch.Size([192])
# Layer: vit.encoder.layer.10.attention.attention.key
# 	Weight shape: vit.encoder.layer.10.attention.attention.key torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.10.attention.attention.key torch.Size([192])
# Layer: vit.encoder.layer.10.attention.attention.value
# 	Weight shape: vit.encoder.layer.10.attention.attention.value torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.10.attention.attention.value torch.Size([192])
# Layer: vit.encoder.layer.10.attention.attention.dropout
# 	No weights vit.encoder.layer.10.attention.attention.dropout
# Layer: vit.encoder.layer.10.attention.output
# 	No weights vit.encoder.layer.10.attention.output
# Layer: vit.encoder.layer.10.attention.output.dense
# 	Weight shape: vit.encoder.layer.10.attention.output.dense torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.10.attention.output.dense torch.Size([192])
# Layer: vit.encoder.layer.10.attention.output.dropout
# 	No weights vit.encoder.layer.10.attention.output.dropout
# Layer: vit.encoder.layer.10.intermediate
# 	No weights vit.encoder.layer.10.intermediate
# Layer: vit.encoder.layer.10.intermediate.dense
# 	Weight shape: vit.encoder.layer.10.intermediate.dense torch.Size([768, 192])
# 	Bias shape: vit.encoder.layer.10.intermediate.dense torch.Size([768])
# Layer: vit.encoder.layer.10.intermediate.intermediate_act_fn
# 	No weights vit.encoder.layer.10.intermediate.intermediate_act_fn
# Layer: vit.encoder.layer.10.output
# 	No weights vit.encoder.layer.10.output
# Layer: vit.encoder.layer.10.output.dense
# 	Weight shape: vit.encoder.layer.10.output.dense torch.Size([192, 768])
# 	Bias shape: vit.encoder.layer.10.output.dense torch.Size([192])
# Layer: vit.encoder.layer.10.output.dropout
# 	No weights vit.encoder.layer.10.output.dropout
# Layer: vit.encoder.layer.10.layernorm_before
# 	Weight shape: vit.encoder.layer.10.layernorm_before torch.Size([192])
# 	Bias shape: vit.encoder.layer.10.layernorm_before torch.Size([192])
# Layer: vit.encoder.layer.10.layernorm_after
# 	Weight shape: vit.encoder.layer.10.layernorm_after torch.Size([192])
# 	Bias shape: vit.encoder.layer.10.layernorm_after torch.Size([192])
# Layer: vit.encoder.layer.11
# 	No weights vit.encoder.layer.11
# Layer: vit.encoder.layer.11.attention
# 	No weights vit.encoder.layer.11.attention
# Layer: vit.encoder.layer.11.attention.attention
# 	No weights vit.encoder.layer.11.attention.attention
# Layer: vit.encoder.layer.11.attention.attention.query
# 	Weight shape: vit.encoder.layer.11.attention.attention.query torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.11.attention.attention.query torch.Size([192])
# Layer: vit.encoder.layer.11.attention.attention.key
# 	Weight shape: vit.encoder.layer.11.attention.attention.key torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.11.attention.attention.key torch.Size([192])
# Layer: vit.encoder.layer.11.attention.attention.value
# 	Weight shape: vit.encoder.layer.11.attention.attention.value torch.Size([192, 192])
# 	Bias shape: vit.encoder.layer.11.attention.attention.value torch.Size([192])
# Layer: vit.encoder.layer.11.attention.attention.dropout
# 	No weights vit.encoder.layer.11.attention.attention.dropout
# Layer: vit.encoder.layer.11.attention.output
# ...
# 	Bias shape: decoder.decoder_layers.2.attention.attention.key torch.Size([192])
# Layer: decoder.decoder_layers.2.attention.attention.value
# 	Weight shape: decoder.decoder_layers.2.attention.attention.value torch.Size([192, 192])
# 	Bias shape: decoder.decoder_layers.2.attention.attention.value torch.Size([192])
# Layer: decoder.decoder_layers.2.attention.attention.dropout
# 	No weights decoder.decoder_layers.2.attention.attention.dropout
# Layer: decoder.decoder_layers.2.attention.output
# 	No weights decoder.decoder_layers.2.attention.output
# Layer: decoder.decoder_layers.2.attention.output.dense
# 	Weight shape: decoder.decoder_layers.2.attention.output.dense torch.Size([192, 192])
# 	Bias shape: decoder.decoder_layers.2.attention.output.dense torch.Size([192])
# Layer: decoder.decoder_layers.2.attention.output.dropout
# 	No weights decoder.decoder_layers.2.attention.output.dropout
# Layer: decoder.decoder_layers.2.intermediate
# 	No weights decoder.decoder_layers.2.intermediate
# Layer: decoder.decoder_layers.2.intermediate.dense
# 	Weight shape: decoder.decoder_layers.2.intermediate.dense torch.Size([768, 192])
# 	Bias shape: decoder.decoder_layers.2.intermediate.dense torch.Size([768])
# Layer: decoder.decoder_layers.2.intermediate.intermediate_act_fn
# 	No weights decoder.decoder_layers.2.intermediate.intermediate_act_fn
# Layer: decoder.decoder_layers.2.output
# 	No weights decoder.decoder_layers.2.output
# Layer: decoder.decoder_layers.2.output.dense
# 	Weight shape: decoder.decoder_layers.2.output.dense torch.Size([192, 768])
# 	Bias shape: decoder.decoder_layers.2.output.dense torch.Size([192])
# Layer: decoder.decoder_layers.2.output.dropout
# 	No weights decoder.decoder_layers.2.output.dropout
# Layer: decoder.decoder_layers.2.layernorm_before
# 	Weight shape: decoder.decoder_layers.2.layernorm_before torch.Size([192])
# 	Bias shape: decoder.decoder_layers.2.layernorm_before torch.Size([192])
# Layer: decoder.decoder_layers.2.layernorm_after
# 	Weight shape: decoder.decoder_layers.2.layernorm_after torch.Size([192])
# 	Bias shape: decoder.decoder_layers.2.layernorm_after torch.Size([192])
# Layer: decoder.decoder_layers.3
# 	No weights decoder.decoder_layers.3
# Layer: decoder.decoder_layers.3.attention
# 	No weights decoder.decoder_layers.3.attention
# Layer: decoder.decoder_layers.3.attention.attention
# 	No weights decoder.decoder_layers.3.attention.attention
# Layer: decoder.decoder_layers.3.attention.attention.query
# 	Weight shape: decoder.decoder_layers.3.attention.attention.query torch.Size([192, 192])
# 	Bias shape: decoder.decoder_layers.3.attention.attention.query torch.Size([192])
# Layer: decoder.decoder_layers.3.attention.attention.key
# 	Weight shape: decoder.decoder_layers.3.attention.attention.key torch.Size([192, 192])
# 	Bias shape: decoder.decoder_layers.3.attention.attention.key torch.Size([192])
# Layer: decoder.decoder_layers.3.attention.attention.value
# 	Weight shape: decoder.decoder_layers.3.attention.attention.value torch.Size([192, 192])
# 	Bias shape: decoder.decoder_layers.3.attention.attention.value torch.Size([192])
# Layer: decoder.decoder_layers.3.attention.attention.dropout
# 	No weights decoder.decoder_layers.3.attention.attention.dropout
# Layer: decoder.decoder_layers.3.attention.output
# 	No weights decoder.decoder_layers.3.attention.output
# Layer: decoder.decoder_layers.3.attention.output.dense
# 	Weight shape: decoder.decoder_layers.3.attention.output.dense torch.Size([192, 192])
# 	Bias shape: decoder.decoder_layers.3.attention.output.dense torch.Size([192])
# Layer: decoder.decoder_layers.3.attention.output.dropout
# 	No weights decoder.decoder_layers.3.attention.output.dropout
# Layer: decoder.decoder_layers.3.intermediate
# 	No weights decoder.decoder_layers.3.intermediate
# Layer: decoder.decoder_layers.3.intermediate.dense
# 	Weight shape: decoder.decoder_layers.3.intermediate.dense torch.Size([768, 192])
# 	Bias shape: decoder.decoder_layers.3.intermediate.dense torch.Size([768])
# Layer: decoder.decoder_layers.3.intermediate.intermediate_act_fn
# 	No weights decoder.decoder_layers.3.intermediate.intermediate_act_fn
# Layer: decoder.decoder_layers.3.output
# 	No weights decoder.decoder_layers.3.output
# Layer: decoder.decoder_layers.3.output.dense
# 	Weight shape: decoder.decoder_layers.3.output.dense torch.Size([192, 768])
# 	Bias shape: decoder.decoder_layers.3.output.dense torch.Size([192])
# Layer: decoder.decoder_layers.3.output.dropout
# 	No weights decoder.decoder_layers.3.output.dropout
# Layer: decoder.decoder_layers.3.layernorm_before
# 	Weight shape: decoder.decoder_layers.3.layernorm_before torch.Size([192])
# 	Bias shape: decoder.decoder_layers.3.layernorm_before torch.Size([192])
# Layer: decoder.decoder_layers.3.layernorm_after
# 	Weight shape: decoder.decoder_layers.3.layernorm_after torch.Size([192])
# 	Bias shape: decoder.decoder_layers.3.layernorm_after torch.Size([192])
# Layer: decoder.decoder_layers.4
# 	No weights decoder.decoder_layers.4
# Layer: decoder.decoder_layers.4.attention
# 	No weights decoder.decoder_layers.4.attention
# Layer: decoder.decoder_layers.4.attention.attention
# 	No weights decoder.decoder_layers.4.attention.attention
# Layer: decoder.decoder_layers.4.attention.attention.query
# 	Weight shape: decoder.decoder_layers.4.attention.attention.query torch.Size([192, 192])
# 	Bias shape: decoder.decoder_layers.4.attention.attention.query torch.Size([192])
# Layer: decoder.decoder_layers.4.attention.attention.key
# 	Weight shape: decoder.decoder_layers.4.attention.attention.key torch.Size([192, 192])
# 	Bias shape: decoder.decoder_layers.4.attention.attention.key torch.Size([192])
# Layer: decoder.decoder_layers.4.attention.attention.value
# 	Weight shape: decoder.decoder_layers.4.attention.attention.value torch.Size([192, 192])
# 	Bias shape: decoder.decoder_layers.4.attention.attention.value torch.Size([192])
# Layer: decoder.decoder_layers.4.attention.attention.dropout
# 	No weights decoder.decoder_layers.4.attention.attention.dropout
# Layer: decoder.decoder_layers.4.attention.output
# 	No weights decoder.decoder_layers.4.attention.output
# Layer: decoder.decoder_layers.4.attention.output.dense
# 	Weight shape: decoder.decoder_layers.4.attention.output.dense torch.Size([192, 192])
# 	Bias shape: decoder.decoder_layers.4.attention.output.dense torch.Size([192])
# Layer: decoder.decoder_layers.4.attention.output.dropout
# 	No weights decoder.decoder_layers.4.attention.output.dropout
# Layer: decoder.decoder_layers.4.intermediate
# 	No weights decoder.decoder_layers.4.intermediate
# Layer: decoder.decoder_layers.4.intermediate.dense
# 	Weight shape: decoder.decoder_layers.4.intermediate.dense torch.Size([768, 192])
# 	Bias shape: decoder.decoder_layers.4.intermediate.dense torch.Size([768])
# Layer: decoder.decoder_layers.4.intermediate.intermediate_act_fn
# 	No weights decoder.decoder_layers.4.intermediate.intermediate_act_fn
# Layer: decoder.decoder_layers.4.output
# 	No weights decoder.decoder_layers.4.output
# Layer: decoder.decoder_layers.4.output.dense
# 	Weight shape: decoder.decoder_layers.4.output.dense torch.Size([192, 768])
# 	Bias shape: decoder.decoder_layers.4.output.dense torch.Size([192])
# Layer: decoder.decoder_layers.4.output.dropout
# 	No weights decoder.decoder_layers.4.output.dropout
# Layer: decoder.decoder_layers.4.layernorm_before
# 	Weight shape: decoder.decoder_layers.4.layernorm_before torch.Size([192])
# 	Bias shape: decoder.decoder_layers.4.layernorm_before torch.Size([192])
# Layer: decoder.decoder_layers.4.layernorm_after
# 	Weight shape: decoder.decoder_layers.4.layernorm_after torch.Size([192])
# 	Bias shape: decoder.decoder_layers.4.layernorm_after torch.Size([192])
# Layer: decoder.decoder_layers.5
# 	No weights decoder.decoder_layers.5
# Layer: decoder.decoder_layers.5.attention
# 	No weights decoder.decoder_layers.5.attention
# Layer: decoder.decoder_layers.5.attention.attention
# 	No weights decoder.decoder_layers.5.attention.attention
# Layer: decoder.decoder_layers.5.attention.attention.query
# 	Weight shape: decoder.decoder_layers.5.attention.attention.query torch.Size([192, 192])
# 	Bias shape: decoder.decoder_layers.5.attention.attention.query torch.Size([192])
# Layer: decoder.decoder_layers.5.attention.attention.key
# 	Weight shape: decoder.decoder_layers.5.attention.attention.key torch.Size([192, 192])
# 	Bias shape: decoder.decoder_layers.5.attention.attention.key torch.Size([192])
# Layer: decoder.decoder_layers.5.attention.attention.value
# 	Weight shape: decoder.decoder_layers.5.attention.attention.value torch.Size([192, 192])
# 	Bias shape: decoder.decoder_layers.5.attention.attention.value torch.Size([192])
# Layer: decoder.decoder_layers.5.attention.attention.dropout
# 	No weights decoder.decoder_layers.5.attention.attention.dropout
# Layer: decoder.decoder_layers.5.attention.output
# 	No weights decoder.decoder_layers.5.attention.output
# Layer: decoder.decoder_layers.5.attention.output.dense
# 	Weight shape: decoder.decoder_layers.5.attention.output.dense torch.Size([192, 192])
# 	Bias shape: decoder.decoder_layers.5.attention.output.dense torch.Size([192])
# Layer: decoder.decoder_layers.5.attention.output.dropout
# 	No weights decoder.decoder_layers.5.attention.output.dropout
# Layer: decoder.decoder_layers.5.intermediate
# 	No weights decoder.decoder_layers.5.intermediate
# Layer: decoder.decoder_layers.5.intermediate.dense
# 	Weight shape: decoder.decoder_layers.5.intermediate.dense torch.Size([768, 192])
# 	Bias shape: decoder.decoder_layers.5.intermediate.dense torch.Size([768])
# Layer: decoder.decoder_layers.5.intermediate.intermediate_act_fn
# 	No weights decoder.decoder_layers.5.intermediate.intermediate_act_fn
# Layer: decoder.decoder_layers.5.output
# 	No weights decoder.decoder_layers.5.output
# Layer: decoder.decoder_layers.5.output.dense
# 	Weight shape: decoder.decoder_layers.5.output.dense torch.Size([192, 768])
# 	Bias shape: decoder.decoder_layers.5.output.dense torch.Size([192])
# Layer: decoder.decoder_layers.5.output.dropout
# 	No weights decoder.decoder_layers.5.output.dropout
# Layer: decoder.decoder_layers.5.layernorm_before
# 	Weight shape: decoder.decoder_layers.5.layernorm_before torch.Size([192])
# 	Bias shape: decoder.decoder_layers.5.layernorm_before torch.Size([192])
# Layer: decoder.decoder_layers.5.layernorm_after
# 	Weight shape: decoder.decoder_layers.5.layernorm_after torch.Size([192])
# 	Bias shape: decoder.decoder_layers.5.layernorm_after torch.Size([192])
# Layer: decoder.decoder_layers.6
# 	No weights decoder.decoder_layers.6
# Layer: decoder.decoder_layers.6.attention
# 	No weights decoder.decoder_layers.6.attention
# Layer: decoder.decoder_layers.6.attention.attention
# 	No weights decoder.decoder_layers.6.attention.attention
# Layer: decoder.decoder_layers.6.attention.attention.query
# 	Weight shape: decoder.decoder_layers.6.attention.attention.query torch.Size([192, 192])
# 	Bias shape: decoder.decoder_layers.6.attention.attention.query torch.Size([192])
# Layer: decoder.decoder_layers.6.attention.attention.key
# 	Weight shape: decoder.decoder_layers.6.attention.attention.key torch.Size([192, 192])
# 	Bias shape: decoder.decoder_layers.6.attention.attention.key torch.Size([192])
# Layer: decoder.decoder_layers.6.attention.attention.value
# 	Weight shape: decoder.decoder_layers.6.attention.attention.value torch.Size([192, 192])
# 	Bias shape: decoder.decoder_layers.6.attention.attention.value torch.Size([192])
# Layer: decoder.decoder_layers.6.attention.attention.dropout
# 	No weights decoder.decoder_layers.6.attention.attention.dropout
# Layer: decoder.decoder_layers.6.attention.output
# 	No weights decoder.decoder_layers.6.attention.output
# Layer: decoder.decoder_layers.6.attention.output.dense
# 	Weight shape: decoder.decoder_layers.6.attention.output.dense torch.Size([192, 192])
# 	Bias shape: decoder.decoder_layers.6.attention.output.dense torch.Size([192])
# Layer: decoder.decoder_layers.6.attention.output.dropout
# 	No weights decoder.decoder_layers.6.attention.output.dropout
# Layer: decoder.decoder_layers.6.intermediate
# 	No weights decoder.decoder_layers.6.intermediate
# Layer: decoder.decoder_layers.6.intermediate.dense
# 	Weight shape: decoder.decoder_layers.6.intermediate.dense torch.Size([768, 192])
# 	Bias shape: decoder.decoder_layers.6.intermediate.dense torch.Size([768])
# Layer: decoder.decoder_layers.6.intermediate.intermediate_act_fn
# 	No weights decoder.decoder_layers.6.intermediate.intermediate_act_fn
# Layer: decoder.decoder_layers.6.output
# 	No weights decoder.decoder_layers.6.output
# Layer: decoder.decoder_layers.6.output.dense
# 	Weight shape: decoder.decoder_layers.6.output.dense torch.Size([192, 768])
# 	Bias shape: decoder.decoder_layers.6.output.dense torch.Size([192])
# Layer: decoder.decoder_layers.6.output.dropout
# 	No weights decoder.decoder_layers.6.output.dropout
# Layer: decoder.decoder_layers.6.layernorm_before
# 	Weight shape: decoder.decoder_layers.6.layernorm_before torch.Size([192])
# 	Bias shape: decoder.decoder_layers.6.layernorm_before torch.Size([192])
# Layer: decoder.decoder_layers.6.layernorm_after
# 	Weight shape: decoder.decoder_layers.6.layernorm_after torch.Size([192])
# 	Bias shape: decoder.decoder_layers.6.layernorm_after torch.Size([192])
# Layer: decoder.decoder_layers.7
# 	No weights decoder.decoder_layers.7
# Layer: decoder.decoder_layers.7.attention
# 	No weights decoder.decoder_layers.7.attention
# Layer: decoder.decoder_layers.7.attention.attention
# 	No weights decoder.decoder_layers.7.attention.attention
# Layer: decoder.decoder_layers.7.attention.attention.query
# 	Weight shape: decoder.decoder_layers.7.attention.attention.query torch.Size([192, 192])
# 	Bias shape: decoder.decoder_layers.7.attention.attention.query torch.Size([192])
# Layer: decoder.decoder_layers.7.attention.attention.key
# 	Weight shape: decoder.decoder_layers.7.attention.attention.key torch.Size([192, 192])
# 	Bias shape: decoder.decoder_layers.7.attention.attention.key torch.Size([192])
# Layer: decoder.decoder_layers.7.attention.attention.value
# 	Weight shape: decoder.decoder_layers.7.attention.attention.value torch.Size([192, 192])
# 	Bias shape: decoder.decoder_layers.7.attention.attention.value torch.Size([192])
# Layer: decoder.decoder_layers.7.attention.attention.dropout
# 	No weights decoder.decoder_layers.7.attention.attention.dropout
# Layer: decoder.decoder_layers.7.attention.output
# 	No weights decoder.decoder_layers.7.attention.output
# Layer: decoder.decoder_layers.7.attention.output.dense
# 	Weight shape: decoder.decoder_layers.7.attention.output.dense torch.Size([192, 192])
# 	Bias shape: decoder.decoder_layers.7.attention.output.dense torch.Size([192])
# Layer: decoder.decoder_layers.7.attention.output.dropout
# 	No weights decoder.decoder_layers.7.attention.output.dropout
# Layer: decoder.decoder_layers.7.intermediate
# 	No weights decoder.decoder_layers.7.intermediate
# Layer: decoder.decoder_layers.7.intermediate.dense
# 	Weight shape: decoder.decoder_layers.7.intermediate.dense torch.Size([768, 192])
# 	Bias shape: decoder.decoder_layers.7.intermediate.dense torch.Size([768])
# Layer: decoder.decoder_layers.7.intermediate.intermediate_act_fn
# 	No weights decoder.decoder_layers.7.intermediate.intermediate_act_fn
# Layer: decoder.decoder_layers.7.output
# 	No weights decoder.decoder_layers.7.output
# Layer: decoder.decoder_layers.7.output.dense
# 	Weight shape: decoder.decoder_layers.7.output.dense torch.Size([192, 768])
# 	Bias shape: decoder.decoder_layers.7.output.dense torch.Size([192])
# Layer: decoder.decoder_layers.7.output.dropout
# 	No weights decoder.decoder_layers.7.output.dropout
# Layer: decoder.decoder_layers.7.layernorm_before
# 	Weight shape: decoder.decoder_layers.7.layernorm_before torch.Size([192])
# 	Bias shape: decoder.decoder_layers.7.layernorm_before torch.Size([192])
# Layer: decoder.decoder_layers.7.layernorm_after
# 	Weight shape: decoder.decoder_layers.7.layernorm_after torch.Size([192])
# 	Bias shape: decoder.decoder_layers.7.layernorm_after torch.Size([192])
# Layer: decoder.decoder_norm
# 	Weight shape: decoder.decoder_norm torch.Size([192])
# 	Bias shape: decoder.decoder_norm torch.Size([192])
# Layer: decoder.decoder_pred
# 	Weight shape: decoder.decoder_pred torch.Size([48, 192])
# 	Bias shape: decoder.decoder_pred torch.Size([48])
